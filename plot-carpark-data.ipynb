# %%
import pandas as pd
aquatics_data_frame = pd.read_csv("aquatics_centre.csv", parse_dates=True)

# %%
aquatics_df = aquatics_data_frame.set_index("Timestamp")

# %%
# %matplotlib inline

# %%
aquatics_df.plot(figsize=(200, 200), lw=2, legend=True)
